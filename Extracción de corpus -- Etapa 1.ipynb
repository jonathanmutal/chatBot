# %% [markdown]
# # Trabajo final data mining

# %% [markdown]
# En este trabajo brindaremos un chat bot de respuestas cortas para IM en español. Primero que nada definiremos una respuesta corta como cualquier turno hasta 3 palabras que ocurren al menos n veces. Iremos probando diferentes n a modo de prueba. El texto anterior a la respuesta corta será llamado contexto

# %% [markdown]
# ## Extracción del corpus

# %% [markdown]
# Debido a que no hay un corpus bien definido para este problema utilizaremos el contexto del chat como texto de entrenamiento, por lo que la respuesta corta será la etiqueta. Utilizaremos mensajes de whatsapp tomadas de nuestras conversaciones.

# %% [markdown]
# ### Procesamiento

# %%
import re
import csv
import pandas as pd
import glob
import matplotlib.pyplot as plt
import numpy as np

from datetime import datetime, timedelta
from string import punctuation
from collections import defaultdict

# %%
files = glob.glob('todos/*')
raw_data = []
for file in files:
    with open(file, 'r') as f:
        raw_data += [f.readlines()]

# %% [markdown]
# Sacaremos la primera línea que de nada sirve
#
# `6/18/17, 16:43 - Los mensajes y llamadas en este chat ahora están protegidos con cifrado de extremo a extremo. Toca para más información.`

# %%
raw_data[0]
# Out:
# ['10/16/17, 17:44 - Messages to this chat and calls are now secured with end-to-end encryption. Tap for more info.\n',
#  '10/16/17, 17:44 - \u202a+54 9 351 328-5957\u202c: https://m.facebook.com/story.php?story_fbid=1490068964433492&id=161872773919791\n',
#  '10/16/17, 17:54 - Daniela Bosch: Hola Te confundiste de numero\n']

# %% [markdown]
# Parte del mismo mensaje :o. Como hacemos? Deberíamos buscar una alternativa

# %%
raw_data[18129] + raw_data[18130] + raw_data[18131]
# Out:
# '9/28/17, 21:16 - \u202a+54 9 3544 56-7886\u202c: Pizzas a la parrilla (de esas cocinadas por un chef pulenta), birras y narguilas! \n\nJueves 28, 20.00hs - After Office de Rosh Hashaná! \n'

# %% [markdown]
# #### Formato lindo
#
# Para ello spliteo cada línea por la primera ocurrencia de ": ". Ver bien si se puede hacer algo con las líneas que no tengan el mismo formato (por ahora la quitamos). Hay un problema con las fechas debido a la configuración de cada telefono. Algunos formatos es mm/dd/yyyy y otros dd/mm/yyyy. Veremos como solucionarlo en un futuro.

# %%
def is_message(text):
    return ': ' in text and '/' in text and ',' in text

def is_continuation(text):
    return '/' not in text or ':' not in text or ',' not in text

def is_beggining(text):
    return 'Messages to this chat and calls are now secured with end-to-end encryption' in text

# at the begining we don't filter any kind of message. Let's see what happend.
info_chat = []
for i, chat in enumerate(raw_data):
    for line in chat:
        line = line.strip('\n')
        if is_beggining(line):
            continue
        if 'location: ' in line:
            continue
        if not is_message(line):
            if is_message(info_chat[len(info_chat)-1][3]):
                if is_continuation(line):
                    # if it is a continuation of a message.
                    info_chat[len(info_chat)-1][3] += '. ' + line
            continue
        info, text = line.split(": ", 1)
        try:
            date, owner = info.split(" - ", 1)
            date, hour = date.split(", ")
        except ValueError:
            if ']' in info:
                date, owner = info.split("] ", 1)
                date, hour = date.split(" ", 1)
                date = date.split("[")[0]
        info_chat.append([i, owner, date, hour, text])

# %% [markdown]
# Ahora guardaremos el corpus en formato csv para hacerlo legible.
#
# Tendrá cinco columnas: numero de chat, persona que escribe el msj, fecha y hora en que se envío, mensaje.
#
# | idchat ||  Owner  ||     Date    || hour ||    Message     |
# |--------||---------||-------------||------||----------------|
# |    1   || Pedrito || 20-05-2017  || 20:10|| hola que haces |
# |    1   ||   Juan  || 21-05-2017  || 12:20|| Todo bien?     |
# |    2   ||   Deme  || 15-07-2017  || 13:15||Me fui al baile |

# %%
len(info_chat)
# Out:
# 186042

# %%
info_chat[:10]
# Out:
# [[0,
#   '\u202a+54 9 351 328-5957\u202c',
#   '10/16/17',
#   '17:44',
#   'https://m.facebook.com/story.php?story_fbid=1490068964433492&id=161872773919791'],
#  [0, 'Daniela Bosch', '10/16/17', '17:54', 'Hola Te confundiste de numero'],
#  [1, 'Ori', '6/10/17', '16:58', '😂😂😂😂😂😂😂😂😂😂'],
#  [1, 'Luciano', '6/10/17', '17:43', 'Que es este lugar 👀'],
#  [1, 'Aida', '6/10/17', '17:44', 'Qur hace este aqui'],
#  [1, 'Aida', '6/10/17', '17:44', '\U0001f923'],
#  [1, 'Caty', '6/10/17', '17:44', 'Bienvenido'],
#  [1,
#   'Luciano',
#   '6/10/17',
#   '17:50',
#   'Vengo a pasarle fotos obscenas e irme ?)'],
#  [1, 'Luciano', '6/10/17', '17:50', 'Pasarles'],
#  [1, 'Caty', '6/10/17', '17:51', '👀']]

# %%
fieldnames = ['id', 'owner', 'date', 'hour', 'message']
with open('corpus.csv', 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames, delimiter=',', quotechar='"', quoting=csv.QUOTE_ALL)
    writer.writeheader()
    
    for idc, owner, date, hour, message in info_chat:
        if message =='':
            continue
        writer.writerow({'id': idc, 'owner': owner, 'date': date, 'hour': hour, 'message': message})

# %% [markdown]
# #### Extracción de respuestas cortas

# %%
from collections import defaultdict, Counter

short_answers = {}
short_answers = defaultdict(lambda: 0, short_answers)
with open('corpus2.csv', 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        short_answers[row['label']] += 1
        
sorted(short_answers.items(), key=lambda x: x[1], reverse=True)[:10]
# Out:
# [('ja', 111),
#  ('si', 16),
#  ('', 6),
#  ('dale', 6),
#  ('eu', 5),
#  ('por', 4),
#  ('see', 4),
#  ('q culia', 3),
#  ('noo', 3),
#  ('gracias', 2)]

# %% [markdown]
# #### Subwords de 3 letras para el contexto

# %%
def to_chars(context):
    chars = []
    for line in context:
        line_to_chars = list(line)
        chars += line_to_chars
    return chars

# %%
CHARS = 3

def to_subwords(context):
    subwords_ctx = {}
    subwords_ctx = defaultdict(lambda: 0, subwords_ctx)
    for i in range(CHARS-1, len(context)-(CHARS-1)):
        subwords_ctx[context[i-(CHARS-1):i+(CHARS-2)]] += 1
    return subwords_ctx

# %%
# TODO: quitar "[", "]" y "'" de los contextos o ver cómo guardarlos
context = {}
context = defaultdict(lambda: {}, context)

with open('corpus2.csv', 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        subwords_ctx = to_subwords(row['context'])
        context[row['label']] = dict(Counter(subwords_ctx) + Counter(context[row['label']]))
print(context['sip'])
# Out:
# {'ert': 1, 'vas': 1, 'owl': 1, 'uen': 2, ' me': 1, ' sh': 1, 'l a': 1, 'r e': 1, 'vis': 1, 'rob': 1, 'ené': 1, 'ati': 1, 'o c': 1, 'ali': 1, 'ry ': 1, 'ue ': 3, 'exa': 1, 'ble': 1, 'ala': 1, 'a y': 2, 's a': 1, 'n t': 1, ' cu': 2, 'ani': 1, 'ués': 1, 'mat': 2, 'da ': 1, 'far': 1, 'she': 1, 'n l': 1, 'ti ': 1, 'pul': 1, 'a n': 2, 'sa ': 1, 'est': 3, 'ori': 1, 'a d': 4, ' en': 2, ' ca': 2, 'ima': 1, 'o m': 1, 'á e': 1, 's e': 5, 'me ': 1, 'mo ': 1, 'ria': 1, 'y q': 1, ' fa': 1, 'ste': 1, 'o l': 1, ' tu': 1, 'tá ': 1, 'esp': 1, 'dad': 2, 'el ': 2, 'sto': 2, 'asa': 1, 'ent': 3, 'uev': 1, ' fo': 1, 'al ': 1, 'sua': 1, 'ese': 2, 'ou ': 1, 'en ': 2, 'tor': 2, 'ta ': 2, 'go ': 1, 'e  ': 1, 'ade': 1, 'nt ': 1, ' la': 3, 'his': 1, 'em ': 1, 'a s': 1, 'cha': 1, ' po': 1, 'e d': 1, 'u p': 1, 'pop': 1, 'asu': 1, 'l m': 1, 'po ': 1, ' an': 1, 'har': 1, ' al': 1, 't j': 1, ' da': 1, ' na': 2, 'e n': 1, 'a m': 1, 'lid': 1, 'o q': 2, 'e h': 1, 'tu ': 1, 'des': 2, 'e b': 1, 'e c': 2, ' bo': 1, 'stá': 2, 'ora': 1, 'do ': 1, 'que': 3, 'ipo': 1, 'l f': 1, 'ual': 1, ' el': 2, ' pr': 1, 'smo': 1, 'ás ': 1, 'ada': 1, ' sa': 1, 'ia ': 1, 'bow': 1, 'arg': 1, 'ado': 1, 'atf': 1, '  e': 1, 'nad': 1, ' nu': 1, 'ma ': 1, 'rgo': 1, 'for': 1, 'cta': 1, 'ist': 2, 'ame': 1, 'to ': 1, 'eva': 1, ' e ': 1, 's c': 1, 'wli': 1, 'spu': 1, 'e s': 1, ' y ': 2, ' ti': 1, 'o t': 1, 'te ': 1, 'na ': 1, 'nim': 1, 'se ': 2, 'e f': 1, 'bía': 1, ' ja': 1, 'ism': 1, 'la ': 5, ' va': 1, 'xac': 1, 'pro': 1, 'emp': 1, 'ten': 1, 'va ': 1, 'mpo': 1, ' co': 1, 'nve': 1, 'opu': 1, 'mis': 1, 'epo': 1, 'tás': 1, 'nta': 2, 'onv': 1, 'abí': 1, 'ía ': 1, 'de ': 3, 'nés': 1, 'hab': 1, 'tid': 1, 'men': 1, 'es ': 2, 'rti': 1, 'as ': 2, 'cto': 1, ' no': 1, 'pué': 1, 'e e': 2, 'tip': 1, 'ida': 1, 'or ': 1, 'm n': 1, 'és ': 2, 'orm': 1, 'cas': 2, ' de': 4, ' hi': 1, 'no ': 1, 'cue': 2, 'a l': 1, 'a t': 1, 'ula': 1, ' te': 2, 'con': 1, 'nou': 1, 'fac': 1, 'a v': 1, 'y e': 1, 'ory': 1, 'a e': 1, 'u c': 1, 'tem': 1, 'hep': 1, 'tfa': 1, 'tam': 1, 'obl': 1, 'lem': 1, 'sas': 1, ' qu': 3, 'sal': 1, 'rma': 1, 'nue': 1, 'ver': 1, ' ha': 1, ' mi': 1, ' es': 7, 'ja ': 2, 'a h': 2, 'i p': 1, 'por': 2, ' ma': 1, 'esa': 1, 'y t': 1, 'act': 2}

# %% [markdown]
# ### N-Gramas

# %%
N = 2

def count_context(sent, n=N):
    c = Counter()
    
    sent_ = ['<s>'] * (n-1) + sent + ['</s>']
    m = len(sent_)
    for i in range(m - n + 1):
        c[tuple(sent_[i:i + n])] += 1
    
    return c

# %%
ngram = defaultdict(Counter)
with open('corpus2.csv', 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        sent = row['context'].split(' ')
        ngram[row['label']] += count_context(sent)

ngram['ja']
# Out:
# Counter({('httpswwwfacebook631433487061081', ''): 1,
#          ('el', 'jdisnabaixnah'): 1,
#          ('de', 'chistes'): 1,
#          ('me', 'hizo'): 1,
#          ('fue', 'haja'): 1,
#          ('digo', 'me'): 1,
#          ('mejor', 'que'): 1,
#          ('tpb', '</s>'): 1,
#          ('a', 'agarrar'): 2,
#          ('guada', 'pa'): 1,
#          ('me', 'divierte'): 1,
#          ('copan', 'uf'): 1,
#          ('al', 'menos'): 2,
#          ('puntualmente', 'me'): 1,
#          ('q', 'ya'): 1,
#          ('hacía', 'falta'): 1,
#          ('bibliografía', 'bue'): 1,
#          ('mano', 'o'): 1,
#          ('con', 'guada'): 1,
#          ('el', 'capitulo'): 1,
#          ('es', 'tpb'): 1,
#          ('para', 'mí'): 1,
#          ('es', 'domingo'): 1,
#          ('globos', 'me'): 1,
#          ('juntada', 'hablamos'): 1,
#          ('publicacion', 'de'): 1,
#          ('una', 'vez'): 2,
#          ('lo', 'importante'): 1,
#          ('bien', 'y'): 1,
#          ('pq', 'nos'): 1,
#          ('ponele', 'toda'): 1,
#          ('si', '</s>'): 1,
#          ('hands', 'a'): 1,
#          ('httpwwwintercambiosvirtualesorgsoftwareformatfactory3multilenguajeespanolconversionentreformatosdevideosonidoeimagen',
#           'tenes'): 1,
#          ('el', 'offline'): 1,
#          ('tyrion', 'le'): 1,
#          ('pensar', 'que'): 1,
#          ('tmb', 'pq'): 2,
#          ('por', 'eso'): 3,
#          ('gusta', 'el'): 1,
#          ('me', 'queda'): 1,
#          ('se', 'me'): 2,
#          ('creo', 'que'): 3,
#          ('ese', 'una'): 1,
#          ('pq', 'ponele'): 1,
#          ('no', 'estaria'): 1,
#          ('chomaso', 'ja'): 1,
#          ('explora', 'ciertas'): 1,
#          ('el', 'nombre'): 2,
#          ('silo', 'estaba'): 1,
#          ('la', 'musicaaaaa'): 1,
#          ('🤔🤔', 'cupido'): 1,
#          ('asesino', 'a'): 1,
#          ('me', 'pasó'): 1,
#          ('serie', 'y'): 1,
#          ('puede', 'ser'): 5,
#          ('que', 'tengo'): 1,
#          ('por', 'lo'): 1,
#          ('del', 'mate'): 1,
#          ('particular', 'pero'): 1,
#          ('mismisimo', 'perro'): 1,
#          ('momento', '</s>'): 1,
#          ('la', 'tengo'): 1,
#          ('molesta', 'para'): 1,
#          ('😊', 'pero'): 1,
#          ('see', 'la'): 1,
#          ('ta', 're'): 1,
#          ('vi', 'got'): 1,
#          ('mano', 'de'): 1,
#          ('ahh', 'pos'): 1,
#          ('x', 'o'): 1,
#          ('me', 'da'): 1,
#          ('si', 'explora'): 1,
#          ('mortaaaaal', 'jij'): 1,
#          ('y', 'el'): 1,
#          ('nada', 'sobre'): 1,
#          ('q', 'la'): 1,
#          ('gente', 'nosotras'): 1,
#          ('capítulo', 'ya'): 1,
#          ('veo', 'si'): 1,
#          ('una', 'mierda'): 1,
#          ('la', 'paso'): 1,
#          ('hollywood', 'me'): 1,
#          ('mi', 'gente'): 1,
#          ('ah', 'ese'): 1,
#          ('la', 'heladera'): 1,
#          ('a', 'hacer'): 1,
#          ('tan', 'inflada'): 1,
#          ('pelis', 'que'): 1,
#          ('un', 'procuto'): 1,
#          ('gente', 'que'): 1,
#          ('lo', 'hablamos'): 1,
#          ('re', 'expandía'): 1,
#          ('como', 'q'): 1,
#          ('menos', 'ya'): 1,
#          ('<s>', 'usa'): 1,
#          ('<s>', 'si'): 2,
#          ('httpwwwmardelplatafilmfestcomesnoticiaabrelaconvocatoriadelconcursodomingodinubila803',
#           'mortal'): 1,
#          ('y', 'lo'): 2,
#          ('funcion', 'parecida'): 1,
#          ('pero', 'me'): 1,
#          ('muy', 'difícil'): 1,
#          ('la', 'reunión'): 1,
#          ('pq', 'cada'): 1,
#          ('ahora', 'hago'): 1,
#          ('pero', 'alto'): 1,
#          ('profecias', 'no'): 1,
#          ('peli', 'enr'): 1,
#          ('de', 'lujo'): 1,
#          ('sé', 'no'): 1,
#          ('tiempo', 'para'): 1,
#          ('si', 'me'): 2,
#          ('fueron', 'ahí'): 1,
#          ('sip', 'qué'): 1,
#          ('enloqueció', 'creo'): 1,
#          ('para', 'qué'): 1,
#          ('ciertas', 'cosas'): 1,
#          ('white', 'walkers'): 1,
#          ('me', 'pa'): 1,
#          ('de', 'abajo'): 1,
#          ('se', 'fueron'): 1,
#          ('si', 'tan'): 1,
#          ('lo', 'haga'): 1,
#          ('ideas', 'ja'): 1,
#          ('nos', 'dan'): 1,
#          ('tengo', 'abierto'): 1,
#          ('divierte', 'verlo'): 1,
#          ('no', 'soy'): 1,
#          ('si', 'muy'): 1,
#          ('que', 'esté'): 1,
#          ('yo', 'la'): 1,
#          ('deja', 'de'): 1,
#          ('último', 'igual'): 1,
#          ('voy', 'a'): 2,
#          ('carilla', '🤔'): 1,
#          ('bien', 'en'): 1,
#          ('ese', 'es'): 1,
#          ('de', 'integrantes'): 1,
#          ('esa', 'longitud'): 1,
#          ('aca', '</s>'): 1,
#          ('su', 'gente'): 1,
#          ('y', 'nada'): 1,
#          ('lo', 'vi'): 1,
#          ('lo', 'viste'): 1,
#          ('revive', 'no'): 1,
#          ('min', 'es'): 1,
#          ('de', 'mardel'): 1,
#          ('los', 'white'): 1,
#          ('es', 'media'): 1,
#          ('pq', 'es'): 1,
#          ('que', 'para'): 1,
#          ('más', 'o'): 1,
#          ('midiendo', 'con'): 1,
#          ('mí', 'tmb'): 1,
#          ('y', 'me'): 1,
#          ('haber', 'dvds'): 1,
#          ('el', 'mail'): 1,
#          ('el', 'anteproyecto'): 1,
#          ('somos', '5'): 1,
#          ('lls', 'años'): 1,
#          ('verla', 'mejor'): 1,
#          ('si', 'es'): 2,
#          ('sabés', 'que'): 1,
#          ('y', 'muy'): 1,
#          ('prefiero', 'mañana'): 1,
#          ('entendiendo', '</s>'): 1,
#          ('ok', 'genial'): 1,
#          ('años', 'que'): 1,
#          ('thormund', 'o'): 1,
#          ('hollywodense', 'se'): 1,
#          ('secundario', 'al'): 1,
#          ('va', 'a'): 1,
#          ('menos', 'sabés'): 1,
#          ('no', 'creo'): 1,
#          ('un', 'poco'): 1,
#          ('en', 'esta'): 1,
#          ('ni', 'a'): 1,
#          ('menor', 'calidad'): 1,
#          ('una', 'mujer'): 1,
#          ('mis', 'más'): 1,
#          ('entendí', 'puede'): 1,
#          ('en', 'el'): 5,
#          ('fin', 'avisame'): 1,
#          ('base', 'a'): 1,
#          ('agua', '</s>'): 1,
#          ('siendo', 'chomaso'): 1,
#          ('un', 'diafragma'): 1,
#          ('primera', 'por'): 1,
#          ('este', 'trailer'): 1,
#          ('cueeec', 'la'): 1,
#          ('hablamos', 'de'): 1,
#          ('pags', 'de'): 1,
#          ('el', 'phisic'): 1,
#          ('llegó', 'el'): 1,
#          ('suelen', 'estar'): 1,
#          ('bastante', 'pero'): 1,
#          ('gustó', 'para'): 1,
#          ('cupido', 'me'): 1,
#          ('<s>', 'sé'): 1,
#          ('la', 'sala'): 1,
#          ('agarrar', 'los'): 1,
#          ('el', 'mismo'): 2,
#          ('triangulo', 'amoroso'): 1,
#          ('sale', 'mkv'): 1,
#          ('a', 'tocar'): 1,
#          ('pa', 'probar'): 1,
#          ('nombre', 'del'): 2,
#          ('lo', 'diegetico'): 1,
#          ('q', 'haber'): 1,
#          ('con', 'tormund'): 1,
#          ('que', 'te'): 1,
#          ('service', 'de'): 1,
#          ('nada', 'que'): 1,
#          ('chomasa', 'parece'): 1,
#          ('pero', 'si'): 2,
#          ('duro', 'igual'): 1,
#          ('qué', 'archivos'): 1,
#          ('vos', 'tipo'): 1,
#          ('y', 'conquistar'): 1,
#          ('conexiones', 'nada'): 1,
#          ('muy', 'pok'): 1,
#          ('las', 'profecias'): 1,
#          ('igual', 'eso'): 1,
#          ('que', 'a'): 1,
#          ('y', 'giladas'): 1,
#          ('heladera', '</s>'): 1,
#          ('no', 'se'): 4,
#          ('dice', 'tu'): 1,
#          ('quiero', 'que'): 1,
#          ('es', 'una'): 6,
#          ('si', 'puede'): 1,
#          ('más', 'ridiculeces'): 1,
#          ('dragón', 'pq'): 1,
#          ('verlo', 'una'): 1,
#          ('digamos', 'si'): 1,
#          ('feminicidios', 'que'): 1,
#          ('fan', 'service'): 1,
#          ('es', 'lo'): 2,
#          ('pq', 'todos'): 1,
#          ('eso', 'digo'): 1,
#          ('hubieses', 'venido'): 1,
#          ('para', 'aca'): 1,
#          ('el', 'país'): 1,
#          ('y', 'breanne'): 1,
#          ('de', 'si'): 1,
#          ('en', 'comparación'): 1,
#          ('lujo', 'nunca'): 1,
#          ('si', 'el'): 1,
#          ('virus', '</s>'): 1,
#          ('dudoso', '</s>'): 1,
#          ('ahí', 'estoy'): 1,
#          ('flaiar', 'con'): 1,
#          ('que', 'descanses'): 1,
#          ('manos', 'si'): 1,
#          ('anclan', 'bastante'): 1,
#          ('q', 'era'): 1,
#          ('ratito', 'escucho'): 1,
#          ('pagas', 'claro'): 1,
#          ('dicen', 'mucho'): 1,
#          ('es', 'sólo'): 1,
#          ('sala', 'de'): 1,
#          ('les', 'da'): 1,
#          ('procuto', 'que'): 1,
#          ('ja', 'ah'): 1,
#          ('sobreusado', 'lo'): 1,
#          ('me', 'parece'): 3,
#          ('y', 'chomaso'): 1,
#          ('nos', 'hackearon'): 1,
#          ('todo', 'el'): 1,
#          ('ya', 'no'): 2,
#          ('cara', 'ya'): 1,
#          ('cosas', 'viendo'): 1,
#          ('míos', 'se'): 1,
#          ('<s>', 'uy'): 1,
#          ('buena', 'candidata'): 1,
#          ('bien', 'faltaba'): 1,
#          ('grande', '😂'): 1,
#          ('<s>', 'sherlock'): 1,
#          ('bocha', 'de'): 1,
#          ('nuestras', 'cuentas'): 1,
#          ('got', 'de'): 1,
#          ('shebien', 'ustedes'): 1,
#          ('guardar', 'todas'): 1,
#          ('ya', 'vio'): 1,
#          ('bue', 'tendrá'): 1,
#          ('muy', 'inocente'): 1,
#          ('artículo', 'ja'): 1,
#          ('tipo', 'el'): 1,
#          ('viene', 'q'): 1,
#          ('eso', 'pregunto'): 1,
#          ('nosotras', 'no'): 1,
#          ('bueno', 'ahi'): 1,
#          ('sucediendo', 'en'): 1,
#          ('haber', 'muerto'): 1,
#          ('david', 'lynch'): 1,
#          ('y', 'la'): 1,
#          ('peri', 'yo'): 1,
#          ('esos', 'errores'): 1,
#          ('y', 'molesta'): 1,
#          ('film', 'un'): 1,
#          ('que', 'quede'): 1,
#          ('a', 'el'): 1,
#          ('anda', 'de'): 1,
#          ('toda', 'mi'): 1,
#          ('mati', 'no'): 1,
#          ('un', 'quizás'): 1,
#          ('que', 'tiene'): 1,
#          ('mantener', 'la'): 1,
#          ('a', 'la'): 1,
#          ('hitchock', 'encambio'): 1,
#          ('<s>', 'lo'): 1,
#          ('las', 'temporadas'): 1,
#          ('hay', 'una'): 1,
#          ('me', 'falla'): 1,
#          ('tenemos', 'que'): 1,
#          ('además', 'no'): 1,
#          ('pablo', 'que'): 1,
#          ('alta', 'hippeada'): 1,
#          ('disaster', '</s>'): 1,
#          ('la', 'version'): 1,
#          ('<s>', 'por'): 3,
#          ('no', 'pueden'): 1,
#          ('usado', 'en'): 1,
#          ('el', 'capítulo'): 2,
#          ('escucho', 'estoy'): 1,
#          ('cabeza', 'porque'): 1,
#          ('era', 'verdad'): 1,
#          ('viste', 'nop'): 1,
#          ('de', 'torrents'): 1,
#          ('estas', 'cosas'): 1,
#          ('mmm', 'capaz'): 1,
#          ('saber', 'pq'): 1,
#          ('jose', '</s>'): 1,
#          ('de', 'pablo'): 1,
#          ('corroborar', 'si'): 1,
#          ('sonar', 'y'): 1,
#          ('referencia', 'a'): 1,
#          ('estar', 'en'): 1,
#          ('eso', 'tambien'): 1,
#          ('las', 'calles'): 1,
#          ('ja', 'me'): 4,
#          ('dos', 'temporadas'): 1,
#          ('más', 'que'): 3,
#          ('me', 'va'): 1,
#          ('de', 'todos'): 1,
#          ('nosotras', 'somos'): 1,
#          ('cordoba', 'de'): 1,
#          ('calles', 'no'): 1,
#          ('nunca', 'me'): 1,
#          ('odio', 'en'): 1,
#          ('errores', 'pasarían'): 1,
#          ('estuve', 'con'): 1,
#          ('lo', 'q'): 1,
#          ('en', 'fin'): 1,
#          ('ahora', 'es'): 1,
#          ('entonces', 'ja'): 1,
#          ('pos', 'no'): 1,
#          ('mierda', ''): 1,
#          ('simpleza', 'pero'): 1,
#          ('haga', 'es'): 1,
#          ('insinuaran', '</s>'): 1,
#          ('ja', 'la'): 1,
#          ('<s>', 'qué'): 1,
#          ('cine', 'nadaaaaa'): 1,
#          ('por', 'flashie'): 1,
#          ('actores', 'no'): 1,
#          ('una', 'telenovela'): 1,
#          ('por', 'favorsito'): 1,
#          ('tendria', 'que'): 1,
#          ('la', 'segunda'): 1,
#          ('mal', 'tenemos'): 1,
#          ('que', 'la'): 1,
#          ('está', 'tan'): 1,
#          ('perfecta', 'representaciónm'): 1,
#          ('igual', 'uds'): 1,
#          ('final', '</s>'): 1,
#          ('esta', 'buena'): 1,
#          ('la', 'banana'): 1,
#          ('y', 'recibirme'): 1,
#          ('pa', 'leer'): 1,
#          ('difícil', 'lo'): 1,
#          ('ja', 'sería'): 1,
#          ('el', 'año'): 1,
#          ('era', 'la'): 1,
#          ('de', 'unayo'): 1,
#          ('quién', 'es'): 1,
#          ('la', 'tutoria'): 1,
#          ('re', 'decayó'): 1,
#          ('', 'bombardeo'): 1,
#          ('flashera', 'como'): 1,
#          ('junto', 'me'): 1,
#          ('calidad', 'pero'): 1,
#          ('el', 'anterior'): 1,
#          ('una', 'buena'): 3,
#          ('sólo', 'hay'): 1,
#          ('hippeada', '</s>'): 1,
#          ('tiene', 'hata'): 1,
#          ('bastante', 'y'): 1,
#          ('probando', 'dale'): 1,
#          ('la', 'bajé'): 1,
#          ('para', 'verlo'): 1,
#          ('🙈', '</s>'): 1,
#          ('de', 'lecturs'): 1,
#          ('pq', 'me'): 2,
#          ('estaba', 'la'): 1,
#          ('<s>', 'httpswwwonlinevideoconvertercomvideoconverter'): 1,
#          ('despue', 'te'): 1,
#          ('o', 'masbien'): 1,
#          ('por', 'skype'): 1,
#          ('para', 'guada'): 1,
#          ('último', 'momento'): 1,
#          ('le', 'preguntaron'): 1,
#          ('carilla', 'ponele'): 1,
#          ('perdiste', 'la'): 1,
#          ('no', 'va'): 1,
#          ('capitulo', 'digo'): 1,
#          ('mi', 'puntualmente'): 1,
#          ('ahi', 'veo'): 1,
#          ('guste', 'dany'): 1,
#          ('una', 'perfecta'): 1,
#          ('suma', 'tmb'): 1,
#          ('diria', 'que'): 1,
#          ('estoy', 'viendo'): 1,
#          ('mardel', 'bueno'): 1,
#          ('había', 'ido'): 1,
#          ('que', 'termine'): 1,
#          ('sip', 'mmm'): 1,
#          ('gustó', 'la'): 1,
#          ('le', 'guste'): 1,
#          ('se', 'pero'): 1,
#          ('pq', 'si'): 2,
#          ('el', 'perro'): 1,
#          ('redirecciono', 'bastante'): 1,
#          ('gracias', 'jose'): 1,
#          ('una', 'carilla'): 2,
#          ('quien', 'se'): 1,
#          ('segundo', 'plano'): 1,
#          ('fui', 'a'): 1,
#          ('diálogos', 'deben'): 1,
#          ('aue', 'las'): 1,
#          ('pero', 'el'): 2,
#          ('70', 'si'): 1,
#          ('jij', 'habrá'): 1,
#          ('<s>', 'salis'): 1,
#          ('esto', 'no'): 2,
#          ('bastante', 'chomasa'): 1,
#          ('😝', '</s>'): 1,
#          ('nadaaaaa', 'hitchock'): 1,
#          ('primera', 'aunque'): 1,
#          ('ser', 'no'): 1,
#          ('un', 'adulto'): 1,
#          ('mi', 'artículín'): 1,
#          ('5', 'nomas'): 1,
#          ('no', 'sé'): 4,
#          ('que', 'el'): 4,
#          ('la', 'beca'): 1,
#          ('pero', 'chomi'): 1,
#          ('por', 'ahí'): 1,
#          ('se', 'tendría'): 1,
#          ('usa', 'adblock'): 1,
#          ('si', 'lo'): 2,
#          ('pero', 'creatividad'): 1,
#          ('en', 'cada'): 1,
#          ('que', 'si'): 1,
#          ('ver', 'qué'): 1,
#          ('festival', 'mal'): 1,
#          ('sólo', 'quiero'): 1,
#          ('q', 'de'): 1,
#          ('fue', 'yo'): 1,
#          ('flashie', 'hace'): 1,
#          ('para', 'bajar'): 1,
#          ('hacer', 'que'): 1,
#          ('mi', 'me'): 1,
#          ('<s>', ''): 2,
#          ('nada', 'yo'): 1,
#          ('si', 'igual'): 1,
#          ('eso', 'es'): 1,
#          ('hollywoodense', 'en'): 1,
#          ('cada', 'cual'): 1,
#          ('en', 'un'): 1,
#          ('está', 'bueno'): 1,
#          ('inflada', 'eso'): 1,
#          ('gustan', '🤔🤔'): 1,
#          ('no', 'volver'): 1,
#          ('para', 'escuchar'): 1,
#          ('capaz', 'nos'): 1,
#          ('un', 'disaster'): 1,
#          ('joyaaa', 'a'): 1,
#          ('puedo', 'pq'): 1,
#          ('encambio', 'si'): 1,
#          ('avanzando', 'pq'): 1,
#          ('enr', 'elación'): 1,
#          ('entre', 'las'): 1,
#          ('se', 'lo'): 1,
#          ('<s>', 'la'): 1,
#          ('chomi', 'al'): 1,
#          ('me', 'colgué'): 1,
#          ('conocidos', '</s>'): 1,
#          ('ido', 'tan'): 1,
#          ('podría', 'pasar'): 1,
#          ('colgué', 'creo'): 1,
#          ('dragón', 'mortaaaaal'): 1,
#          ('más', 'nada'): 1,
#          ('claro', 'claro'): 1,
#          ('ahi', 'dejar'): 1,
#          ('a', 'los'): 1,
#          ('congelar', 'loopear'): 1,
#          ('la', 'simpleza'): 1,
#          ('cruel', '</s>'): 1,
#          ('lo', 'menos'): 1,
#          ('con', 'el'): 1,
#          ('tengo', 'el'): 1,
#          ('tengo', 'muchas'): 1,
#          ('pasó', 'pensar'): 1,
#          ('no', 'conocidos'): 1,
#          ('silabas', 'p'): 1,
#          ('hago', 'lo'): 1,
#          ('ya', 'igual'): 1,
#          ('eso', 'suma'): 1,
#          ('comparación', 'con'): 1,
#          ('eh', 'me'): 1,
#          ('por', 'el'): 2,
#          ('consumidomasticado', 'que'): 1,
#          ('ja', 'ja'): 1,
#          ('fue', 'tipo'): 1,
#          ('ja', 'pagas'): 1,
#          ('la', 'serie'): 1,
#          ('hice', 'toda'): 1,
#          ('pero', 'voy'): 1,
#          ('ja', 'si'): 5,
#          ('puedo', 'igual'): 1,
#          ('merchandising', 'se'): 1,
#          ('muere', 'asi'): 1,
#          ('vio', 'mi'): 1,
#          ('que', 're'): 1,
#          ('mal', 'bueno'): 1,
#          ('ja', 'pero'): 2,
#          ('del', 'mercado'): 1,
#          ('años', 'es'): 1,
#          ('ja', 'see'): 1,
#          ('ja', 'los'): 1,
#          ('qui', '</s>'): 1,
#          ('festivales', '🙄'): 1,
#          ('el', 'corazón'): 1,
#          ('si', 'revive'): 1,
#          ('eso', 'lo'): 1,
#          ('si', 'hubieses'): 1,
#          ('no', 'pesanada'): 1,
#          ('una', 'sóla'): 1,
#          ('archivos', 'falta'): 1,
#          ('lo', 'van'): 1,
#          ('hayan', 'matado'): 1,
#          ('que', 'haber'): 2,
#          ('fuerte', 'igual'): 1,
#          ('súper', 'hollywodense'): 1,
#          ('único', '😰'): 1,
#          ('chomaso', 'lo'): 1,
#          ('es', 'como'): 1,
#          ('que', 'era'): 1,
#          ('hollywoodense', 'que'): 1,
#          ('todos', 'ja'): 1,
#          ('me', 'cagarn'): 1,
#          ('da', 'en'): 1,
#          ('estás', 'midiendo'): 1,
#          ('ojo', 'que'): 1,
#          ('del', 'medio'): 1,
#          ('eso', 'digamos'): 1,
#          ('las', 'tomas'): 2,
#          ('mañ', 'veo'): 1,
#          ('<s>', 'o'): 1,
#          ('ahora', 'lo'): 1,
#          ('eso', 'vo'): 1,
#          ('me', 'paso'): 1,
#          ('corto', '</s>'): 1,
#          ('vas', 'a'): 2,
#          ('tendría', 'q'): 1,
#          ('cercanos', 'ja'): 1,
#          ('o', 'con'): 1,
#          ('no', 'me'): 4,
#          ('capítulo', 'pero'): 1,
#          ('murió', 'súper'): 1,
#          ('de', 'todo'): 1,
#          ('esta', 'ja'): 1,
#          ('cómo', 'veían'): 1,
#          ('con', 'los'): 1,
#          ('ser', 'que'): 2,
#          ('<s>', '😪'): 1,
#          ('cara', 'del'): 1,
#          ('mi', 'corto'): 1,
#          ('🤔', 'hoy'): 1,
#          ('tipo', 'tuvo'): 1,
#          ('y', 'redirecciono'): 1,
#          ('a', 'quien'): 1,
#          ('flashie', 'eb'): 1,
#          ('ja', 'de'): 1,
#          ('httpswwwonlinevideoconvertercomvideoconverter', 'ah'): 1,
#          ('mas', 'tiempo'): 1,
#          ('al', 'finnn'): 1,
#          ('pelis', 'no'): 1,
#          ('lo', 'insinuaran'): 1,
#          ('una', 'lectura'): 1,
#          ('mercado', '</s>'): 1,
#          ('caso', 'en'): 1,
#          ('que', 'preguntarseloal'): 1,
#          ('si', 'y'): 1,
#          ('y', 'eso'): 1,
#          ('alto', 'viruson'): 1,
#          ('buena', 'referencia'): 1,
#          ('mí', 'las'): 1,
#          ('volver', 'a'): 1,
#          ('formato', 'parecio'): 1,
#          ('viene', 'cold'): 1,
#          ('cordarse', 'que'): 1,
#          ('recien', 'con'): 1,
#          ('exponen', 'ahí'): 1,
#          ('sip', 'fue'): 1,
#          ('21', 'actores'): 1,
#          ('puede', 'ver'): 1,
#          ('youtube', 'está'): 1,
#          ('😰', 'que'): 1,
#          ('lamentablemente', 'es'): 1,
#          ('tendrá', 'más'): 1,
#          ('mismo', 'tipo'): 1,
#          ('queda', 'esa'): 1,
#          ('nomas', '</s>'): 1,
#          ('que', 'nada'): 1,
#          ('que', 'hayan'): 1,
#          ('<s>', 'ja'): 19,
#          ('el', 'otro'): 1,
#          ('y', 'es'): 1,
#          ('longitud', 'httpswwwfacebook631433487061081'): 1,
#          ('habia', 'spoileado'): 1,
#          ('ya', 'lo'): 1,
#          ('se', 'entiende'): 1,
#          ('genial', 'si'): 1,
#          ('telenovela', 'bastante'): 1,
#          ('de', 'su'): 1,
#          ('que', 'consiguen'): 1,
#          ('país', 'cueeec'): 1,
#          ('ahhh', 'mal'): 1,
#          ('director', 'ja'): 1,
#          ('tmb', '🤔'): 1,
#          ('😂', 'tan'): 1,
#          ('probar', 'en'): 1,
#          ('<s>', 'saraaaaa'): 1,
#          ('loopear', 'montajear'): 1,
#          ('no', 'plantea'): 1,
#          ('veían', 'esa'): 1,
#          ('beca', 'bueno'): 1,
#          ('cuenta', 'ni'): 1,
#          ('acordarse', 'el'): 1,
#          ('de', 'gente'): 1,
#          ('', '</s>'): 2,
#          ('nota', 'q'): 1,
#          ('bueno', 'que'): 1,
#          ('a', 'tener'): 1,
#          ('pensada', 'por'): 1,
#          ('vos', '😝'): 1,
#          ('la', 'veré'): 1,
#          ('no', 'entendí'): 2,
#          ('pa', 'q'): 1,
#          ('asi', 'que'): 2,
#          ('menos', 'la'): 1,
#          ('bajé', 'de'): 1,
#          ('pq', 'tmb'): 1,
#          ('muchas', 'en'): 1,
#          ('q', 'es'): 1,
#          ('probe', 'recien'): 1,
#          ('sip', 'a'): 1,
#          ('50', '70'): 1,
#          ('den', 'bola'): 1,
#          ('digo', 'de'): 1,
#          ('ja', 'a'): 1,
#          ('ya', 'te'): 1,
#          ('y', 'que'): 1,
#          ('mueran', 'todos'): 1,
#          ('año', 'q'): 1,
#          ('son', 'los'): 1,
#          ('no', '</s>'): 1,
#          ('<s>', 'viajeson'): 1,
#          ('a', 'salvarlo'): 1,
#          ('es', 'un'): 3,
#          ('decís', 'pq'): 1,
#          ('pa', 'explorar'): 1,
#          ('más', 'experiencia'): 1,
#          ('busca', 'conexiones'): 1,
#          ('que', 'esta'): 1,
#          ('pasar', 'bibliografía'): 1,
#          ('tenemos', 'q'): 1,
#          ('system', 'cordobes'): 1,
#          ('no', 'tr'): 1,
#          ('🤔', 'está'): 1,
#          ('te', 'cuento'): 1,
#          ('inocente', 'ahi'): 1,
#          ('los', 'links'): 1,
#          ('si', ''): 1,
#          ('no', 'es'): 2,
#          ('links', 'ja'): 1,
#          ('pasarían', 'a'): 1,
#          ('<s>', 'teng'): 1,
#          ('ultimos', 'años'): 1,
#          ('es', 'muy'): 2,
#          ('de', 'nuevo'): 1,
#          ('sei', 'claro'): 1,
#          ('bueno', 'la'): 1,
#          ('muy', 'bueno'): 1,
#          ('ahí', 'no'): 1,
#          ('palabra', 'contactos'): 1,
#          ('se', 'cumplan'): 1,
#          ('los', 'términos'): 1,
#          ('tan', 'bien'): 1,
#          ('cerveza', 'mati'): 1,
#          ('los', 'odio'): 1,
#          ('elación', 'a'): 1,
#          ('plantea', 'nada'): 1,
#          ('🤔', 'es'): 1,
#          ('<s>', 'tmb'): 1,
#          ('hicimos', 'hasta'): 1,
#          ('no', 'voy'): 1,
#          ('circulan', 'en'): 1,
#          ('ja', 'dale'): 1,
#          ('tan', 'shebien'): 1,
#          ('entendí', 'ja'): 1,
#          ('q', 'piden'): 1,
#          ('lo', 'estás'): 1,
#          ('lo', 'reconoció'): 1,
#          ('note', 'q'): 1,
#          ('sintesis', 'pq'): 1,
#          ('queda', 'ahí'): 1,
#          ('tendría', 'que'): 1,
#          ('estoy', 'seguro'): 1,
#          ('digamos', 'claro'): 1,
#          ('la', 'tendría'): 1,
#          ('amour', '</s>'): 1,
#          ('complacernos', 'a'): 1,
#          ('las', 'publicaciones'): 1,
#          ('segunda', 'pero'): 1,
#          ('q', 'mover'): 1,
#          ('mepa', 'que'): 1,
#          ('da', 'bola'): 1,
#          ('q', 'prefiero'): 1,
#          ('esa', 'mano'): 1,
#          ('esté', 'sobreusado'): 1,
#          ('con', 'un'): 1,
#          ('grupo', '</s>'): 1,
#          ('si', 'da'): 1,
#          ('está', 'en'): 1,
#          ('pueden', 'complacernos'): 1,
#          ('el', 'tipo'): 1,
#          ('eb', 'mi'): 1,
#          ('gente', 'ya'): 1,
#          ('los', 'dos'): 1,
#          ('tipo', 'de'): 1,
#          ('menos', 'el'): 1,
#          ('robaron', 'nuestras'): 1,
#          ('demasiado', 'david'): 1,
#          ('tutoria', 'no'): 1,
#          ('lo', 'comercial'): 1,
#          ('seguro', 'mepa'): 1,
#          ('y', 'los'): 2,
#          ('pobre', 'disco'): 1,
#          ('alguien', 'por'): 1,
#          ('mucho', 'gusto'): 1,
#          ('soy', 'una'): 1,
#          ('en', 'cuenta'): 1,
#          ('es', 'eso'): 1,
#          ('dejar', 'esa'): 1,
#          ('las', 'cosas'): 1,
#          ('me', 'gusto'): 1,
#          ('mano', 'puede'): 1,
#          ('me', 'copan'): 1,
#          ('falta', 'refragarmelo'): 1,
#          ('pero', 'decis'): 1,
#          ('claro', 'pasa'): 1,
#          ('vez', 'que'): 1,
#          ('un', 'ratito'): 1,
#          ('el', 'mismisimo'): 1,
#          ('ahí', 'y'): 1,
#          ('las', 'que'): 1,
#          ('mí', 'tendría'): 1,
#          ('bola', '</s>'): 1,
#          ('copia', 'del'): 1,
#          ('entendí', '</s>'): 1,
#          ('uds', 'son'): 1,
#          ('flecha', 'de'): 1,
#          ('habría', 'que'): 1,
#          ('pero', 'por'): 1,
#          ('insinuando', 'sigue'): 1,
#          ('que', 'remarla'): 1,
#          ('cumplan', 'ya'): 1,
#          ('gusta', 'la'): 1,
#          ('buena', 'vida'): 1,
#          ('capítulo', 'me'): 1,
#          ('la', 'equivalencia'): 1,
#          ('de', 'youtube'): 1,
#          ('uy', 'eran'): 1,
#          ('después', 'la'): 2,
#          ('matibere95hotmailcom', 'no'): 1,
#          ('recorder', 'y'): 1,
#          ('contactos', 'ja'): 1,
#          ('pa', 'hacer'): 1,
#          ('paso', 'mas'): 1,
#          ('de', 'una'): 2,
#          ('bue', 'pero'): 1,
#          ('bueno', 'rearmando'): 1,
#          ('no', 'para'): 1,
#          ('mezclan', 'las'): 1,
#          ('se', '50'): 1,
#          ('una', 'funcion'): 1,
#          ('un', 'archivo'): 1,
#          ('pero', 'alta'): 1,
#          ('disco', 'tuvo'): 1,
#          ('raramente', 'ja'): 1,
#          ('me', 'acuerdo'): 1,
#          ('viruson', '🙈'): 1,
#          ('o', 'el'): 1,
#          ('<s>', 'asi'): 1,
#          ('eso', 'otra'): 1,
#          ('montado', 'a'): 1,
#          ('profe', 'me'): 1,
#          ('al', 'final'): 1,
#          ('se', 'pasó'): 1,
#          ('a', 'spoilear'): 1,
#          ('querei', '</s>'): 1,
#          ('larga', 'igual'): 1,
#          ('haber', '21'): 1,
#          ('bueno', 'a'): 1,
#          ('moría', 'puede'): 1,
#          ('en', 'una'): 1,
#          ('<s>', 'noup'): 1,
#          ('al', 'pedo'): 1,
#          ('algo', 'pa'): 2,
#          ('chomaso', 'aunque'): 1,
#          ('suiquiera', 'nada'): 1,
#          ('las', 'manos'): 1,
#          ('no', 'hay'): 1,
#          ('hy', 'fui'): 1,
#          ('eran', 'para'): 1,
#          ('en', 'mardel'): 1,
#          ('<s>', 'es'): 1,
#          ('los', 'audios'): 1,
#          ('preguntarseloal', '80'): 1,
#          ('<s>', 'genial'): 1,
#          ('oscars', 'de'): 1,
#          ('de', 'los'): 3,
#          ('<s>', 'dale'): 1,
#          ('una', 'claqueta'): 1,
#          ('otra', 'manera'): 1,
#          ('de', 'uso'): 1,
#          ('exportado', 'nomas'): 1,
#          ('<s>', 'ahhh'): 1,
#          ('equivalencia', 'no'): 1,
#          ('ponele', 'y'): 1,
#          ('serio', 'y'): 1,
#          ('se', 'moría'): 1,
#          ('saraaaaa', '</s>'): 1,
#          ('😭', 'quiero'): 1,
#          ('falla', '</s>'): 1,
#          ('género', 'por'): 1,
#          ('diafragma', 'una'): 1,
#          ('bola', 'si'): 1,
#          ('eso', 'en'): 1,
#          ('re', 'avanzando'): 1,
#          ('un', 'asesino'): 1,
#          ('ahi', 'en'): 1,
#          ('cara', 'ja'): 1,
#          ('nos', 'promocionan'): 1,
#          ('tiro', 'alto'): 1,
#          ('una', 'flecha'): 1,
#          ('el', 'cine'): 2,
#          ('da', 'igual'): 1,
#          ('tres', 'silabas'): 1,
#          ('<s>',
#           'httpwwwmardelplatafilmfestcomesnoticiaabrelaconvocatoriadelconcursodomingodinubila803'): 1,
#          ('todas', 'me'): 1,
#          ('nomas', 'pero'): 2,
#          ('salis', 'bien'): 1,
#          ('diegetico', 'no'): 1,
#          ('me', 'bajé'): 1,
#          ('veo', 'y'): 1,
#          ('si', 'no'): 3,
#          ('digo', 'por'): 1,
#          ('mujer', 'por'): 1,
#          ('a', 'luchar'): 1,
#          ('mejor', 'ja'): 1,
#          ('ponele', 'la'): 1,
#          ('walkers', 'thormund'): 1,
#          ('del', 'vob'): 1,
#          ('si', 'estaba'): 1,
#          ('no', 'pq'): 1,
#          ('tipo', 'snoopy'): 1,
#          ('modificando', 'mi'): 1,
#          ('vara', 'en'): 1,
#          ('es', 'sobre'): 1,
#          ('onda', 'entre'): 1,
#          ('audios', 'ja'): 1,
#          ('tmb', '</s>'): 1,
#          ('por', 'ahi'): 1,
#          ('ay', 'esto'): 1,
#          ('realidad', 'no'): 1,
#          ('lo', 'de'): 3,
#          ('que', 'lo'): 2,
#          ('anterior', 'peri'): 1,
#          ('pero', 'al'): 1,
#          ('parecida', 'a'): 1,
#          ('genial', 'después'): 1,
#          ('<s>', 'sip'): 3,
#          ('nada', 'es'): 1,
#          ('ay', 'si'): 1,
#          ('que', 'estaban'): 1,
#          ('spoileado', 'varias'): 1,
#          ('temporadas', 'ja'): 1,
#          ('ni', 'siquiera'): 1,
#          ('te', 'anclan'): 1,
#          ('pareció', 'ja'): 1,
#          ('en', 'particular'): 1,
#          ('por', 'qué'): 1,
#          ('para', 'una'): 1,
#          ('sherlock', 'revive'): 1,
#          ('que', 'ver'): 4,
#          ('el', 'género'): 1,
#          ('mejor', 'nomas'): 1,
#          ('reunión', 'asi'): 1,
#          ('nada', 'como'): 1,
#          ('si', 'era'): 1,
#          ('p', '</s>'): 1,
#          ('manera', 'ja'): 1,
#          ('que', 'dura'): 1,
#          ('ja', 'ya'): 1,
#          ('min', 'no'): 1,
#          ('para', 'nada'): 1,
#          ('cosas', '</s>'): 1,
#          ('vi', 'bue'): 1,
#          ('version', 'final'): 1,
#          ('como', 'que'): 1,
#          ('mismo', 'corto'): 1,
#          ('venían', 'insinuando'): 1,
#          ('refragarmelo', 'en'): 1,
#          ('fiel', 'que'): 1,
#          ('viendo', 'sólo'): 1,
#          ('seminario', 'no'): 1,
#          ('el', 'anima'): 1,
#          ('cold', 'hands'): 1,
#          ('ni', 'suiquiera'): 1,
#          ('todos', 'los'): 1,
#          ('una', 'intención'): 1,
#          ('noche', 'hoy'): 1,
#          ('pasa', 'q'): 1,
#          ('estaban', 'sucediendo'): 1,
#          ('finnn', '</s>'): 1,
#          ('abierto', 'para'): 1,
#          ('el', 'trono'): 1,
#          ('ahí', 'ojo'): 1,
#          ('nos', 'había'): 1,
#          ('y', 'condiciones'): 1,
#          ('venido', 'tiraba'): 1,
#          ('sé', 'que'): 1,
#          ('a', 'cordarse'): 1,
#          ('parece', 'que'): 1,
#          ('deben', 'haber'): 1,
#          ('los', 'feminicidios'): 1,
#          ('quería', 'corroborar'): 1,
#          ('lo', 'miro'): 1,
#          ('con', 'la'): 4,
#          ('<s>', 'gerardo'): 1,
#          ('en', 'pen'): 1,
#          ('<s>', 'pq'): 1,
#          ('brevemente', '</s>'): 1,
#          ('tenes', 'idea'): 1,
#          ('cosa', 'no'): 1,
#          ('dura', '60'): 1,
#          ('tormund', 'si'): 1,
#          ('te', 'pasé'): 1,
#          ('<s>', 'fue'): 1,
#          ('60', 'min'): 1,
#          ('ja', 'pobre'): 1,
#          ('biblio', 'pa'): 1,
#          ('varias', 'cosas'): 1,
#          ('para', '</s>'): 1,
#          ('calidad', 'muy'): 1,
#          ('que', 'es'): 2,
#          ('o', 'sea'): 1,
#          ('che', 'te'): 1,
#          ('me', 'den'): 1,
#          ('quedo', 'con'): 1,
#          ('piden', 'ja'): 1,
#          ('nomas', 'y'): 1,
#          ('se', 'fue'): 1,
#          ('intención', 'en'): 1,
#          ('igual', 'creo'): 1,
#          ('paginas', '</s>'): 1,
#          ('siquiera', 'un'): 1,
#          ('a', 'seguir'): 1,
#          ('es', 'grande'): 1,
#          ('que', 'está'): 1,
#          ('pok', 'face'): 1,
#          ('quiero', 'saber'): 1,
#          ('alto', 'virus'): 1,
#          ('esas', 'pelis'): 1,
#          ('muy', 'cruel'): 1,
#          ('medio', 'no'): 1,
#          ...})

# %%
# %store ngram
# Out:
# Stored 'ngram' (defaultdict)
